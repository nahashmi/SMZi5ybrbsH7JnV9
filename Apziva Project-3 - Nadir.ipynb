# %% [markdown]
# # Apziva Project-3

# %% [markdown]
# Importing the required libraries

# %%
import pandas as pd
import numpy as np
#import sklearn

import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\nahas\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# Loading the data

# %%
df_main = pd.read_csv('potential-talents - Aspiring human resources - seeking human resources.csv', encoding='unicode_escape')
df_main
# Out:
#       id                                          job_title  \
# 0      1  2019 C.T. Bauer College of Business Graduate (...
# 1      2  Native English Teacher at EPIK (English Progra...
# 2      3              Aspiring Human Resources Professional
# 3      4             People Development Coordinator at Ryan
# 4      5    Advisory Board Member at Celal Bayar University
# ..   ...                                                ...
# 99   100  Aspiring Human Resources Manager | Graduating ...
# 100  101              Human Resources Generalist at Loparex
# 101  102   Business Intelligence and Analytics at Travelers
# 102  103                     Always set them up for Success
# 103  104   Director Of Administration at Excellence Logging
#
#                                 location connection  fit
# 0                         Houston, Texas         85  NaN
# 1                                 Kanada      500+   NaN
# 2    Raleigh-Durham, North Carolina Area         44  NaN
# ...

# %%
df_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          104 non-null    int64
#  1   job_title   104 non-null    object
#  2   location    104 non-null    object
#  3   connection  104 non-null    object
#  4   fit         0 non-null      float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 4.2+ KB

# %%
df_main.shape
# Out:
# (104, 5)

# %%
df_main.describe()
# Out:
#                id  fit
# count  104.000000  0.0
# mean    52.500000  NaN
# std     30.166206  NaN
# min      1.000000  NaN
# 25%     26.750000  NaN
# 50%     52.500000  NaN
# 75%     78.250000  NaN
# max    104.000000  NaN

# %% [markdown]
# ##### Checking NULL values

# %%
df_main.isnull()
# Out:
#         id  job_title  location  connection   fit
# 0    False      False     False       False  True
# 1    False      False     False       False  True
# 2    False      False     False       False  True
# 3    False      False     False       False  True
# 4    False      False     False       False  True
# ..     ...        ...       ...         ...   ...
# 99   False      False     False       False  True
# 100  False      False     False       False  True
# 101  False      False     False       False  True
# 102  False      False     False       False  True
# 103  False      False     False       False  True
#
# [104 rows x 5 columns]

# %%
df_main[df_main.notnull()].count()
# Out:
# id            104
# job_title     104
# location      104
# connection    104
# fit             0
# dtype: int64

# %%
df_main[df_main.isnull()].count()
# Out:
# id            0
# job_title     0
# location      0
# connection    0
# fit           0
# dtype: int64

# %%
df_main.isnull().sum()
# Out:
# id              0
# job_title       0
# location        0
# connection      0
# fit           104
# dtype: int64

# %% [markdown]
# This shows that there are no NULL values in the data set except for the 'fit' score.

# %% [markdown]
# ### Text preprocessing

# %% [markdown]
# ##### 1. changing all alphabets to lower case

# %%
df_main['job_title'] = df_main['job_title'].str.lower()
df_main.head()
# Out:
#    id                                          job_title  \
# 0   1  2019 c.t. bauer college of business graduate (...
# 1   2  native english teacher at epik (english progra...
# 2   3              aspiring human resources professional
# 3   4             people development coordinator at ryan
# 4   5    advisory board member at celal bayar university
#
#                               location connection  fit
# 0                       Houston, Texas         85  NaN
# 1                               Kanada      500+   NaN
# 2  Raleigh-Durham, North Carolina Area         44  NaN
# 3                        Denton, Texas      500+   NaN
# 4                     Ä°zmir, TÃ¼rkiye      500+   NaN

# %% [markdown]
# ##### 2. Expanding the abbreviations

# %%
df_main[df_main['job_title'].str.contains('HR')]
# Out:
# Empty DataFrame
# Columns: [id, job_title, location, connection, fit]
# Index: []

# %%
df_main['job_title'] = df_main['job_title'].str.replace('hr', 'human resources')
df_main['job_title'] = df_main['job_title'].str.replace('chro', 'chief human resources officer')
df_main['job_title'] = df_main['job_title'].str.replace('hro', 'human resources officer')
df_main.head(10)
# Out:
#    id                                          job_title  \
# 0   1  2019 c.t. bauer college of business graduate (...
# 1   2  native english teacher at epik (english progra...
# 2   3              aspiring human resources professional
# 3   4             people development coordinator at ryan
# 4   5    advisory board member at celal bayar university
# 5   6                aspiring human resources specialist
# 6   7  student at humber college and aspiring human r...
# 7   8                  human resources senior specialist
# 8   9  student at humber college and aspiring human r...
# 9  10  seeking human resources human resourcesis and ...
#
#                               location connection  fit
# 0                       Houston, Texas         85  NaN
# 1                               Kanada      500+   NaN
# 2  Raleigh-Durham, North Carolina Area         44  NaN
# 3                        Denton, Texas      500+   NaN
# 4                     Ä°zmir, TÃ¼rkiye      500+   NaN
# ...

# %%
df_main[df_main['job_title'].str.contains('HR')]
# Out:
# Empty DataFrame
# Columns: [id, job_title, location, connection, fit]
# Index: []

# %%
df_main['job_title'] = df_main['job_title'].str.replace('bauer','')
df_main['job_title'] = df_main['job_title'].str.replace('svp','senior vice president')
df_main['job_title'] = df_main['job_title'].str.replace('csr','corporate social responsability')
df_main['job_title'] = df_main['job_title'].str.replace('gphr','global professional in human resources')
df_main['job_title'] = df_main['job_title'].str.replace('sphr','senior professional in human resources')
df_main['job_title'] = df_main['job_title'].str.replace('mes','manufacturing execution system')
df_main['job_title'] = df_main['job_title'].str.replace('hris','human resources information system')
df_main.head()
# Out:
#    id                                          job_title  \
# 0   1  2019 c.t.  college of business graduate (magna...
# 1   2  native english teacher at epik (english progra...
# 2   3              aspiring human resources professional
# 3   4             people development coordinator at ryan
# 4   5    advisory board member at celal bayar university
#
#                               location connection  fit
# 0                       Houston, Texas         85  NaN
# 1                               Kanada      500+   NaN
# 2  Raleigh-Durham, North Carolina Area         44  NaN
# 3                        Denton, Texas      500+   NaN
# 4                     Ä°zmir, TÃ¼rkiye      500+   NaN

# %% [markdown]
# ##### 3. Spelling correction

# %%
# Define a dictionary to map incorrect values to correct ones
corrections = {'Kanada': 'Canada'}
# Apply the corrections using the map() function
df_main['location'] = df_main['location'].map(corrections)
print(df_main)
# Out:
#       id                                          job_title location  \
# 0      1  2019 c.t.  college of business graduate (magna...      NaN
# 1      2  native english teacher at epik (english progra...   Canada
# 2      3              aspiring human resources professional      NaN
# 3      4             people development coordinator at ryan      NaN
# 4      5    advisory board member at celal bayar university      NaN
# ..   ...                                                ...      ...
# 99   100  aspiring human resources manager | graduating ...      NaN
# 100  101              human resources generalist at loparex      NaN
# 101  102   business intelligence and analytics at travelers      NaN
# 102  103                     always set them up for success      NaN
# 103  104   director of administration at excellence logging      NaN
#
#     connection  fit
# 0           85  NaN
# 1        500+   NaN
# 2           44  NaN
# 3        500+   NaN
# 4        500+   NaN
# ...

# %%
df_main['location'] = df_main['location'].str.replace('Kanada', 'Canada')

# %%
df_main
# Out:
#       id                                          job_title location  \
# 0      1  2019 c.t.  college of business graduate (magna...      NaN
# 1      2  native english teacher at epik (english progra...   Canada
# 2      3              aspiring human resources professional      NaN
# 3      4             people development coordinator at ryan      NaN
# 4      5    advisory board member at celal bayar university      NaN
# ..   ...                                                ...      ...
# 99   100  aspiring human resources manager | graduating ...      NaN
# 100  101              human resources generalist at loparex      NaN
# 101  102   business intelligence and analytics at travelers      NaN
# 102  103                     always set them up for success      NaN
# 103  104   director of administration at excellence logging      NaN
#
#     connection  fit
# 0           85  NaN
# 1        500+   NaN
# 2           44  NaN
# 3        500+   NaN
# 4        500+   NaN
# ...

# %% [markdown]
# ##### Creating methods to further preprocess, lemmatize and tokenize the 'job_title' and then use cosine similarity to match the applicants

# %%
#pip uninstall numpy

# %%
#pip install numpy==1.23 --user

# %%
import numpy
numpy.__version__
# Out:
# '1.23.0'

# %%
from nltk.corpus import stopwords
from collections import Counter
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.tokenize.treebank import TreebankWordDetokenizer
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import gensim
from sklearn.metrics.pairwise import cosine_similarity

# %%
df_copy = df_main.copy(deep = True)
df_copy['job_title_cleaned'] = df_copy.loc[:, 'job_title']
df_copy.replace('500+ ','500', inplace=True)
df_copy['connection'] = pd.to_numeric(df_copy['connection'])

stop_words = stopwords.words('english')
stopwords_dict = Counter(stop_words)
lemmatizer = WordNetLemmatizer()

for ind, row in df_copy.iterrows():
    words = [lemmatizer.lemmatize(word) for word in word_tokenize(row['job_title_cleaned'])]
    words = [word.lower() for word in words if word.isalpha()]
    filtered_words = [word for word in words if word.lower() not in stopwords.words('english')]
    df_copy.loc[ind,'job_title_cleaned'] = ' '.join(TreebankWordDetokenizer().detokenize(filtered_words).lower().split())
    df_copy.loc[ind,'job_title_cleaned'] = df_copy.loc[ind,'job_title_cleaned'].replace('bauer','').lstrip()
    df_copy.loc[ind,'job_title_cleaned'] = df_copy.loc[ind,'job_title_cleaned'].replace('svp','senior vice president').lstrip()
    df_copy.loc[ind,'job_title_cleaned'] = df_copy.loc[ind,'job_title_cleaned'].replace('csr','corporate social responsability').lstrip()
    df_copy.loc[ind,'job_title_cleaned'] = df_copy.loc[ind,'job_title_cleaned'].replace('chro','chief human resources officer').lstrip()
    df_copy.loc[ind,'job_title_cleaned'] = df_copy.loc[ind,'job_title_cleaned'].replace('gphr','global professional in human resources').lstrip()
    df_copy.loc[ind,'job_title_cleaned'] = df_copy.loc[ind,'job_title_cleaned'].replace('sphr','senior professional in human resources').lstrip()
    df_copy.loc[ind,'job_title_cleaned'] = df_copy.loc[ind,'job_title_cleaned'].replace('mes','manufacturing execution system').lstrip()
    df_copy.loc[ind,'job_title_cleaned'] = df_copy.loc[ind,'job_title_cleaned'].replace('hris','human resources information system').lstrip()
    df_copy.loc[ind,'job_title_cleaned'] = df_copy.loc[ind,'job_title_cleaned'].replace('hr','human resource').lstrip()

# %%
tokenizer=Tokenizer()
tokenizer.fit_on_texts(df_copy.job_title_cleaned)
tokenized_documents=tokenizer.texts_to_sequences(df_copy.job_title_cleaned)
tokenized_paded_documents=pad_sequences(tokenized_documents,maxlen=40,padding='post')
vocab_size=len(tokenizer.word_index)+1

# %%
print('Size of vocabulary: \n', vocab_size)
print('\ntokenized documents: \n',tokenized_documents)
print('\nPadded tokenized documents: \n',tokenized_paded_documents)
# Out:
# Size of vocabulary:
#  173
#
# tokenized documents:
# ...

# %% [markdown]
# ### Word2Vec

# %%
W2V_PATH= r'C:\Users\nahas\Downloads\Apziva\GoogleNews-vectors-negative300.bin'

# %%
model_w2v = gensim.models.KeyedVectors.load_word2vec_format(W2V_PATH, binary=True)

# %% [markdown]
# Calculating embedding matrix

# %%
embedding_matrix=np.zeros((vocab_size,300))
for word,i in tokenizer.word_index.items():
    if word in model_w2v:
        embedding_matrix[i]=model_w2v[word]
        
print(embedding_matrix.shape)

document_word_embeddings=np.zeros((len(tokenized_paded_documents),40,300))
for i in range(len(tokenized_paded_documents)):
    for j in range(len(tokenized_paded_documents[0])):
        document_word_embeddings[i][j]=embedding_matrix[tokenized_paded_documents[i][j]]
document_word_embeddings.shape
# Out:
# (173, 300)
# (104, 40, 300)

# %% [markdown]
# ###### Method for Pre-processing the key-phrases the same way data are preprocessed

# %%
def processing(query_l):
    for query in query_l:
        words = [lemmatizer.lemmatize(word) for word in word_tokenize(query)]
        words=[word.lower() for word in words if word.isalpha()]
        filtered_words = [word for word in words if word.lower() not in stopwords.words('english')]
        query = ' '.join(TreebankWordDetokenizer().detokenize(filtered_words).lower().split())
        query = query.replace('bauer','').lstrip()
        query = query.replace('svp','senior vice president').lstrip()
        query = query.replace('csr','corporate social responsability').lstrip()
        query = query.replace('chro','chief human resources officer').lstrip()
        query = query.replace('gphr','global professional in human resources').lstrip()
        query = query.replace('sphr','senior professional in human resources').lstrip()
        query = query.replace('mes','manufacturing execution system').lstrip()
        query = query.replace('hris','human resources information system').lstrip()
        query = query.replace('hr','human resource').lstrip()
    
    tokenizer.fit_on_texts(query_l)
    tokenized_documents=tokenizer.texts_to_sequences(query_l)
    tokenized_paded_documents=pad_sequences(tokenized_documents,maxlen=40,padding='post')
    vocab_size=len(tokenizer.word_index)+1
    embedding_matrix=np.zeros((vocab_size,300))
    for word,i in tokenizer.word_index.items():
        if word in model_w2v:
            embedding_matrix[i]=model_w2v[word]

    # creating document-word embeddings
    query_document_word_embeddings=np.zeros((len(tokenized_paded_documents),40,300))
    for i in range(len(tokenized_paded_documents)):
        for j in range(len(tokenized_paded_documents[0])):
            query_document_word_embeddings[i][j]=embedding_matrix[tokenized_paded_documents[i][j]]
    return query_document_word_embeddings

# %% [markdown]
# ###### Method for calculating cosine_similarity

# %%
def get_w2v_query_similarity(document_word_embeddings, query):
    """
    query_w2v: processing the query
    model_w2v: word2vec embedding for all docs
    query: query doc

    return: cosine similarity between query and all docs

    """
    query_w2v = processing(query)
    
    nsamples, nx, ny = query_w2v.shape
    query_w2v_reshape = query_w2v.reshape((nsamples,nx*ny))
    nsamples, nx, ny = document_word_embeddings.shape
    document_word_embeddings_reshape = document_word_embeddings.reshape((nsamples,nx*ny))
    cos_sim_w2v = cosine_similarity(query_w2v_reshape, document_word_embeddings_reshape).flatten()
    return cos_sim_w2v

# %% [markdown]
# ###### Method for listing top n candidates

# %%
def top_candidates(n, by, ascending = False, min_con = 0, location = df_copy.location):
    
    df2 = df_copy.loc[(df_copy.connection >= min_con) & (df_copy.location == location)].sort_values(by = by, ascending = ascending).head(n).copy()
    
    return df2

# %% [markdown]
# ###### Running the program to find the 'fit' score based on word2vec

# %%
from nltk.tokenize.treebank import TreebankWordDetokenizer

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
q1 = "Aspiring human resources"
q2 = 'seeking human resources'
processing(q1)
processing(q2)
t1 = get_w2v_query_similarity(document_word_embeddings, [q1])
t2 = get_w2v_query_similarity(document_word_embeddings, [q2])
print(type(t1))
cos_sim_w2v = np.zeros(len(t1))
for ind,_ in enumerate(t1):
    if t1[ind]>= t2[ind]:
        cos_sim_w2v[ind] =t1[ind]
    else:
        cos_sim_w2v[ind] =t2[ind]
df_copy['fit_word2vec'] = cos_sim_w2v
# Out:
# <class 'numpy.ndarray'>

# %%
df_copy
# Out:
#       id                                          job_title location  \
# 0      1  2019 c.t.  college of business graduate (magna...      NaN
# 1      2  native english teacher at epik (english progra...   Canada
# 2      3              aspiring human resources professional      NaN
# 3      4             people development coordinator at ryan      NaN
# 4      5    advisory board member at celal bayar university      NaN
# ..   ...                                                ...      ...
# 99   100  aspiring human resources manager | graduating ...      NaN
# 100  101              human resources generalist at loparex      NaN
# 101  102   business intelligence and analytics at travelers      NaN
# 102  103                     always set them up for success      NaN
# 103  104   director of administration at excellence logging      NaN
#
#      connection  fit                                  job_title_cleaned  \
# ...

# %% [markdown]
# ###### Find the top candidates

# %%
top_candidates(n = 104, by = 'fit_word2vec', ascending = False, min_con = 0)
# Out:
#     id                                          job_title location  \
# 19  20  native english teacher at epik (english progra...   Canada
# 1    2  native english teacher at epik (english progra...   Canada
# 15  16  native english teacher at epik (english progra...   Canada
# 31  32  native english teacher at epik (english progra...   Canada
# 44  45  native english teacher at epik (english progra...   Canada
# 6    7  student at humber college and aspiring human r...   Canada
# 8    9  student at humber college and aspiring human r...   Canada
# 24  25  student at humber college and aspiring human r...   Canada
# 36  37  student at humber college and aspiring human r...   Canada
# 38  39  student at humber college and aspiring human r...   Canada
# 49  50  student at humber college and aspiring human r...   Canada
# 51  52  student at humber college and aspiring human r...   Canada
#
#     connection  fit                                  job_title_cleaned  \
# ...

# %% [markdown]
# ##### Recalculation based on a 'starred candidate'

# %%
# Candidate at row index 24 has been starred, as an example
starred = df_copy.iloc[24, 1]
starred
# Out:
# 'student at humber college and aspiring human resources generalist'

# %%
processing(starred)
t3 = get_w2v_query_similarity(document_word_embeddings, [starred])
print(type(t3))
cos_sim_w2v = np.zeros(len(t3))
for ind,_ in enumerate(t3):
    cos_sim_w2v[ind] =t3[ind]
df_copy['fit_word2vec'] = cos_sim_w2v
# Out:
# <class 'numpy.ndarray'>

# %%
top_candidates(n = 104, by = 'fit_word2vec', ascending = False, min_con = 0)
# Out:
#     id                                          job_title location  \
# 6    7  student at humber college and aspiring human r...   Canada
# 8    9  student at humber college and aspiring human r...   Canada
# 24  25  student at humber college and aspiring human r...   Canada
# 36  37  student at humber college and aspiring human r...   Canada
# 38  39  student at humber college and aspiring human r...   Canada
# 49  50  student at humber college and aspiring human r...   Canada
# 51  52  student at humber college and aspiring human r...   Canada
# 1    2  native english teacher at epik (english progra...   Canada
# 15  16  native english teacher at epik (english progra...   Canada
# 19  20  native english teacher at epik (english progra...   Canada
# 31  32  native english teacher at epik (english progra...   Canada
# 44  45  native english teacher at epik (english progra...   Canada
#
#     connection  fit                                  job_title_cleaned  \
# ...

# %% [markdown]
# ----- END -----
